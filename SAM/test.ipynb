# %%
import os 
import torch 

from segment_anything import SamPredictor, sam_model_registry
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 5
#       2 import torch
#       4 from segment_anything import SamPredictor, sam_model_registry
# ----> 5 from segment_anything import SamAutomaticMask
#
# ImportError: cannot import name 'SamAutomaticMask' from 'segment_anything' (/home/tnguyen10/.conda/envs/gpu_env/lib/python3.10/site-packages/segment_anything/__init__.py)

# %%
Generator, sam_model_registry
sam = sam_model_registry["<model_type>"](checkpoint="<path/to/checkpoint>")
mask_generator = SamAutomaticMaskGenerator(sam)
masks = mask_generator.generate(<your_image>)
